# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt

import plotly.graph_objects as go
import plotly.express as px
import ipywidgets as widgets

# %% [markdown]
# # ข้อมูลเปิดเผยของกระทรวงการคลัง(API,csv)

# %% [markdown]
# # 1. มูลค่าการนำเข้า แบ่งตามปี 2560-2566

# %%
url = "https://dataservices.mof.go.th/api/data/importexport/data_by_product_country?from=2017-01-01&to=2023-01-01&detail=country&type=import"
# headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url)
# , headers=headers
import60_66 = result.json()
# import60_66

# %%
import60_66 = pd.DataFrame.from_dict(import60_66['items'])
df_import60_66 = pd.DataFrame.from_dict(import60_66['items'])
dictionary = df_import60_66['items']
dictionary = dict(dictionary)
# dictionary
# # metaDF = { 'baht_amnt' : [], 'year_month' : [], 'name' : [], 'key' : [] }
dict_data_df_import60_66 = []
for index in dictionary:
   for data in dictionary[index]:
     dict_data_df_import60_66.append(data)

# dict_data_df_import60_66

# %%
data_df_import60_66 = pd.DataFrame.from_dict(dict_data_df_import60_66)
data_df_import60_66.head(5)
# Out:
#       baht_amnt       year_month  name key
# 0  219946598.00      มกราคม 2560  กรีซ  GR
# 1  148400659.00  กุมภาพันธ์ 2560  กรีซ  GR
# 2  104233035.00      มีนาคม 2560  กรีซ  GR
# 3   89959057.00      เมษายน 2560  กรีซ  GR
# 4   94639558.00     พฤษภาคม 2560  กรีซ  GR

# %%
data_df_import60_66[['month','year']] = data_df_import60_66['year_month'].str.split(' ', expand=True)
data_df_import60_66.head(5)
# Out:
#       baht_amnt       year_month  name key       month  year
# 0  219946598.00      มกราคม 2560  กรีซ  GR      มกราคม  2560
# 1  148400659.00  กุมภาพันธ์ 2560  กรีซ  GR  กุมภาพันธ์  2560
# 2  104233035.00      มีนาคม 2560  กรีซ  GR      มีนาคม  2560
# 3   89959057.00      เมษายน 2560  กรีซ  GR      เมษายน  2560
# 4   94639558.00     พฤษภาคม 2560  กรีซ  GR     พฤษภาคม  2560

# %% [markdown]
# Table new_df_import60_66

# %%
new_df_import60_66 = data_df_import60_66.drop('year_month', axis = 1)
# new_df_import60_66.to_excel('import60_66_file.xlsx', index=True)
new_df_import60_66
# Out:
#           baht_amnt  name key       month  year
# 0      219946598.00  กรีซ  GR      มกราคม  2560
# 1      148400659.00  กรีซ  GR  กุมภาพันธ์  2560
# 2      104233035.00  กรีซ  GR      มีนาคม  2560
# 3       89959057.00  กรีซ  GR      เมษายน  2560
# 4       94639558.00  กรีซ  GR     พฤษภาคม  2560
# ...             ...   ...  ..         ...   ...
# 15870   61344390.00  เฮติ  HT     กันยายน  2565
# 15871   29404671.00  เฮติ  HT      ตุลาคม  2565
# 15872   23967150.00  เฮติ  HT   พฤศจิกายน  2565
# 15873     222046.00  เฮติ  HT     ธันวาคม  2565
# 15874    2079362.00  เฮติ  HT      มกราคม  2566
#
# [15875 rows x 5 columns]

# %% [markdown]
# ผลรวมมูลค่าการนำเข้า แบ่งตามปี

# %%
new_df_import60_66['baht_amnt'] = new_df_import60_66['baht_amnt'].astype(float)

df_import_sum = new_df_import60_66.groupby('year').sum()
df_import_sum = df_import_sum['baht_amnt']
df_import_sum
# Out:
# year
# 2560    7.587118e+12
# 2561    8.064039e+12
# 2562    7.425649e+12
# 2563    6.476267e+12
# 2564    8.540763e+12
# 2565    1.056964e+13
# 2566    8.667371e+11
# Name: baht_amnt, dtype: float64

# %%
data_amnt_import60_66 = pd.DataFrame(list(df_import_sum.items()), columns=['year_import','baht_amnt'])
data_amnt_import60_66
# Out:
#   year_import     baht_amnt
# 0        2560  7.587118e+12
# 1        2561  8.064039e+12
# 2        2562  7.425649e+12
# 3        2563  6.476267e+12
# 4        2564  8.540763e+12
# 5        2565  1.056964e+13
# 6        2566  8.667371e+11

# %% [markdown]
# #2. มูลค่าการส่งออก แบ่งตามปี 2560-2566

# %%
url = "https://dataservices.mof.go.th/api/data/importexport/data_by_product_country?from=2017-01-01&to=2023-01-01&detail=country&type=export"
result = requests.get(url)
export60_66 = result.json()

# %%
export60_66 = pd.DataFrame.from_dict(export60_66['items'])
df_export60_66 = pd.DataFrame.from_dict(export60_66['items'])
dictionary = df_export60_66['items']
dictionary = dict(dictionary)
dictionary
# metaDF = { 'baht_amnt' : [], 'year_month' : [], 'name' : [], 'key' : [] }
dict_data_df_export60_66 = []
for index in dictionary:
   for data in dictionary[index]:
     dict_data_df_export60_66.append(data)

# %%
data_df_export60_66 = pd.DataFrame.from_dict(dict_data_df_export60_66)
data_df_export60_66.head(5)
# Out:
#       baht_amnt       year_month  name key
# 0  160130509.00      มกราคม 2560  กรีซ  GR
# 1  168496893.00  กุมภาพันธ์ 2560  กรีซ  GR
# 2  262620243.00      มีนาคม 2560  กรีซ  GR
# 3  195542863.00      เมษายน 2560  กรีซ  GR
# 4  246679243.00     พฤษภาคม 2560  กรีซ  GR

# %%
data_df_export60_66[['month','year']] = data_df_export60_66['year_month'].str.split(' ', expand=True)
data_df_export60_66.head(5)
# Out:
#       baht_amnt       year_month  name key       month  year
# 0  160130509.00      มกราคม 2560  กรีซ  GR      มกราคม  2560
# 1  168496893.00  กุมภาพันธ์ 2560  กรีซ  GR  กุมภาพันธ์  2560
# 2  262620243.00      มีนาคม 2560  กรีซ  GR      มีนาคม  2560
# 3  195542863.00      เมษายน 2560  กรีซ  GR      เมษายน  2560
# 4  246679243.00     พฤษภาคม 2560  กรีซ  GR     พฤษภาคม  2560

# %% [markdown]
# Table new_df_export60_66

# %%
new_df_export60_66 = data_df_export60_66.drop('year_month', axis = 1)

# new_df_export60_66.to_excel('export60_66_file.xlsx', index=True)
new_df_export60_66
# Out:
#           baht_amnt  name key       month  year
# 0      160130509.00  กรีซ  GR      มกราคม  2560
# 1      168496893.00  กรีซ  GR  กุมภาพันธ์  2560
# 2      262620243.00  กรีซ  GR      มีนาคม  2560
# 3      195542863.00  กรีซ  GR      เมษายน  2560
# 4      246679243.00  กรีซ  GR     พฤษภาคม  2560
# ...             ...   ...  ..         ...   ...
# 16694    5465534.00  เฮติ  HT     กันยายน  2565
# 16695   10928080.00  เฮติ  HT      ตุลาคม  2565
# 16696          1.00  เฮติ  HT   พฤศจิกายน  2565
# 16697   28930534.00  เฮติ  HT     ธันวาคม  2565
# 16698      16927.00  เฮติ  HT      มกราคม  2566
#
# [16699 rows x 5 columns]

# %% [markdown]
# ผลรวมมูลค่าการส่งออก แบ่งตามปี

# %%
new_df_export60_66['baht_amnt'] = new_df_export60_66['baht_amnt'].astype(float)

df_export_sum = new_df_export60_66.groupby('year').sum()
df_export_sum = df_export_sum['baht_amnt']
df_export_sum
# Out:
# year
# 2560    8.006265e+12
# 2561    8.108300e+12
# 2562    7.628400e+12
# 2563    7.183568e+12
# 2564    8.568940e+12
# 2565    9.957073e+12
# 2566    7.126056e+11
# Name: baht_amnt, dtype: float64

# %%
data_amnt_export60_66 = pd.DataFrame(list(df_export_sum.items()), columns=['year_export','baht_amnt'])
data_amnt_export60_66
# Out:
#   year_export     baht_amnt
# 0        2560  8.006265e+12
# 1        2561  8.108300e+12
# 2        2562  7.628400e+12
# 3        2563  7.183568e+12
# 4        2564  8.568940e+12
# 5        2565  9.957073e+12
# 6        2566  7.126056e+11

# %% [markdown]
# # กราฟ bar มูลค่าการส่งออก-นำเข้า ของไทย ย้อนหลัง 6 ปี

# %%
fig = go.Figure()
# ,marker=dict(color= '#85D2D0'),marker=dict(color = '#F4B9B8')

fig.add_trace(go.Bar(x=data_amnt_import60_66['year_import'], y=data_amnt_import60_66['baht_amnt']/1e12,
                     name='นำเข้า', hovertemplate='ปี: %{x}<br>มูลค่า: %{y:,.2f} ล้านล้านบาท'))
fig.add_trace(go.Bar(x=data_amnt_export60_66['year_export'], y=data_amnt_export60_66['baht_amnt']/1e12,
                     name='ส่งออก', hovertemplate='ปี: %{x}<br>มูลค่า: %{y:,.2f} ล้านล้านบาท'))

# Update the layout of the chart
fig.update_layout(title={'text': 'มูลค่าการส่งออก-นำเข้า ของไทย ย้อนหลัง 6 ปี',
                          'y': 0.9,
                          'x': 0.5,
                          'xanchor': 'center',
                          'yanchor': 'top'},
                  xaxis_title='ปี',
                  yaxis_title='มูลค่า (ล้านล้านบาท)',
                  yaxis = dict(tickformat =',.0f'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # ข้อมูลเปิดเผยกระทรวงพาณิชน์ แบ่งตามเดือน ปี 2565

# %% [markdown]
# เดือน มกราคม

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=1&limit=100"
result = requests.get(url)
value_balance1 = result.json()
data_value_balance1 = pd.DataFrame.from_dict(value_balance1)
data_value_balance1
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022      1           CN               CHINA                 จีน
# 1   2022      1           JP               JAPAN             ญี่ปุ่น
# 2   2022      1           US              U.S.A.        สหรัฐอเมริกา
# 3   2022      1           MY            MALAYSIA            มาเลเซีย
# 4   2022      1           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022      1           BY             BELARUS             เบลารุส
# 96  2022      1           RW              RWANDA              รวันดา
# 97  2022      1           HN            HONDURAS            ฮอนดูรัส
# 98  2022      1           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 99  2022      1           VE           VENEZUELA          เวเนซุเอลา
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.473292e+09          2.473292e+09       8.240713e+10
# ...

# %% [markdown]
# เดือน กุมภาพันธ์

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=2&limit=100"
result = requests.get(url)
value_balance2 = result.json()
data_value_balance2 = pd.DataFrame.from_dict(value_balance2)
data_value_balance2
# Out:
#     year  month country_code country_name_en country_name_th  \
# 0   2022      2           CN           CHINA             จีน
# 1   2022      2           US          U.S.A.    สหรัฐอเมริกา
# 2   2022      2           JP           JAPAN         ญี่ปุ่น
# 3   2022      2           MY        MALAYSIA        มาเลเซีย
# 4   2022      2           VN         VIETNAM        เวียดนาม
# ..   ...    ...          ...             ...             ...
# 95  2022      2           SD           SUDAN           ซูดาน
# 96  2022      2           FJ            FIJI            ฟิจิ
# 97  2022      2           LI   LIECHTENSTEIN     ลิกเตนสไตน์
# 98  2022      2           HN        HONDURAS        ฮอนดูรัส
# 99  2022      2           TN         TUNISIA        ตูนิเซีย
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.668489e+09          5.141781e+09       8.759155e+10
# 1       3.896567e+09          7.469407e+09       1.279025e+11
# ...

# %% [markdown]
# เดือน มีนาคม

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=3&limit=100"
result = requests.get(url)
value_balance3 = result.json()
data_value_balance3 = pd.DataFrame.from_dict(value_balance3)
data_value_balance3
# Out:
#     year  month country_code country_name_en country_name_th  \
# 0   2022      3           CN           CHINA             จีน
# 1   2022      3           US          U.S.A.    สหรัฐอเมริกา
# 2   2022      3           JP           JAPAN         ญี่ปุ่น
# 3   2022      3           MY        MALAYSIA        มาเลเซีย
# 4   2022      3           VN         VIETNAM        เวียดนาม
# ..   ...    ...          ...             ...             ...
# 95  2022      3           LB         LEBANON         เลบานอน
# 96  2022      3           UY         URUGUAY        อุรุกวัย
# 97  2022      3           LI   LIECHTENSTEIN     ลิกเตนสไตน์
# 98  2022      3           TN         TUNISIA        ตูนิเซีย
# 99  2022      3           SD           SUDAN           ซูดาน
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       3.204265e+09          8.346046e+09       1.024038e+11
# 1       4.443639e+09          1.191305e+10       1.420125e+11
# ...

# %% [markdown]
# เดือน เมษายน

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=4&limit=100"
result = requests.get(url)
value_balance4 = result.json()
data_value_balance4 = pd.DataFrame.from_dict(value_balance4)
data_value_balance4
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022      4           CN               CHINA                 จีน
# 1   2022      4           US              U.S.A.        สหรัฐอเมริกา
# 2   2022      4           JP               JAPAN             ญี่ปุ่น
# 3   2022      4           MY            MALAYSIA            มาเลเซีย
# 4   2022      4           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022      4           LI       LIECHTENSTEIN         ลิกเตนสไตน์
# 96  2022      4           TN             TUNISIA            ตูนิเซีย
# 97  2022      4           UY             URUGUAY            อุรุกวัย
# 98  2022      4           PY            PARAGUAY            ปารากวัย
# 99  2022      4           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       3.017637e+09          1.136368e+10       1.003440e+11
# ...

# %% [markdown]
# เดือน พฤษภาคม

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=5&limit=100"
result = requests.get(url)
value_balance5 = result.json()
data_value_balance5 = pd.DataFrame.from_dict(value_balance5)
data_value_balance5
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022      5           CN               CHINA                 จีน
# 1   2022      5           US              U.S.A.        สหรัฐอเมริกา
# 2   2022      5           JP               JAPAN             ญี่ปุ่น
# 3   2022      5           MY            MALAYSIA            มาเลเซีย
# 4   2022      5           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022      5           UY             URUGUAY            อุรุกวัย
# 96  2022      5           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 97  2022      5           TL         TIMOR-LESTE        ติมอร์-เลสเต
# 98  2022      5           VU             VANUATU            วานูอาตู
# 99  2022      5           TN             TUNISIA            ตูนิเซีย
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       3.788220e+09          1.515190e+10       1.268788e+11
# ...

# %% [markdown]
# เดือน มิถุนายน

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=6&limit=100"
result = requests.get(url)
value_balance6 = result.json()
data_value_balance6 = pd.DataFrame.from_dict(value_balance6)
data_value_balance6
# Out:
#     year  month country_code     country_name_en          country_name_th  \
# 0   2022      6           CN               CHINA                      จีน
# 1   2022      6           US              U.S.A.             สหรัฐอเมริกา
# 2   2022      6           JP               JAPAN                  ญี่ปุ่น
# 3   2022      6           MY            MALAYSIA                 มาเลเซีย
# 4   2022      6           VN             VIETNAM                 เวียดนาม
# ..   ...    ...          ...                 ...                      ...
# 95  2022      6           ZZ     CONTIQUOUS ZONE  เขตต่อเนื่องราชอาณาจักร
# 96  2022      6           LI       LIECHTENSTEIN              ลิกเตนสไตน์
# 97  2022      6           UY             URUGUAY                 อุรุกวัย
# 98  2022      6           DO  DOMINICAN REPUBLIC       สาธารณรัฐโดมินิกัน
# 99  2022      6           NR               NAURU                   นาอูรู
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# ...

# %% [markdown]
# เดือน กรกฎาคม

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=7&limit=100"

result = requests.get(url)
value_balance7 = result.json()
data_value_balance7 = pd.DataFrame.from_dict(value_balance7)
data_value_balance7
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022      7           CN               CHINA                 จีน
# 1   2022      7           US              U.S.A.        สหรัฐอเมริกา
# 2   2022      7           JP               JAPAN             ญี่ปุ่น
# 3   2022      7           MY            MALAYSIA            มาเลเซีย
# 4   2022      7           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022      7           NR               NAURU              นาอูรู
# 96  2022      7           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 97  2022      7           UY             URUGUAY            อุรุกวัย
# 98  2022      7           LI       LIECHTENSTEIN         ลิกเตนสไตน์
# 99  2022      7           VU             VANUATU            วานูอาตู
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.766251e+09          2.122231e+10       9.705337e+10
# ...

# %% [markdown]
# เดือน สิงหาคม

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=8&limit=100"
result = requests.get(url)
value_balance8 = result.json()
data_value_balance8 = pd.DataFrame.from_dict(value_balance8)
data_value_balance8
# Out:
#     year  month country_code     country_name_en       country_name_th  \
# 0   2022      8           CN               CHINA                   จีน
# 1   2022      8           US              U.S.A.          สหรัฐอเมริกา
# 2   2022      8           JP               JAPAN               ญี่ปุ่น
# 3   2022      8           MY            MALAYSIA              มาเลเซีย
# 4   2022      8           AE    U. ARAB EMIRATES  สหรัฐอาหรับเอมิเรตส์
# ..   ...    ...          ...                 ...                   ...
# 95  2022      8           DO  DOMINICAN REPUBLIC    สาธารณรัฐโดมินิกัน
# 96  2022      8           VU             VANUATU              วานูอาตู
# 97  2022      8           UY             URUGUAY              อุรุกวัย
# 98  2022      8           BY             BELARUS               เบลารุส
# 99  2022      8           BJ               BENIN                 เบนิน
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# ...

# %% [markdown]
# เดือน กันยายน

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=9&limit=100"
result = requests.get(url)
value_balance9 = result.json()
data_value_balance9 = pd.DataFrame.from_dict(value_balance9)
data_value_balance9
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022      9           CN               CHINA                 จีน
# 1   2022      9           US              U.S.A.        สหรัฐอเมริกา
# 2   2022      9           JP               JAPAN             ญี่ปุ่น
# 3   2022      9           MY            MALAYSIA            มาเลเซีย
# 4   2022      9           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022      9           BJ               BENIN               เบนิน
# 96  2022      9           PY            PARAGUAY            ปารากวัย
# 97  2022      9           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 98  2022      9           UY             URUGUAY            อุรุกวัย
# 99  2022      9           LI       LIECHTENSTEIN         ลิกเตนสไตน์
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.698547e+09          2.667068e+10       9.620292e+10
# ...

# %% [markdown]
# เดือน ตุลาคม

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=10&limit=100"
result = requests.get(url)
value_balance10 = result.json()
data_value_balance10 = pd.DataFrame.from_dict(value_balance10)
data_value_balance10
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022     10           CN               CHINA                 จีน
# 1   2022     10           US              U.S.A.        สหรัฐอเมริกา
# 2   2022     10           JP               JAPAN             ญี่ปุ่น
# 3   2022     10           MY            MALAYSIA            มาเลเซีย
# 4   2022     10           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022     10           PY            PARAGUAY            ปารากวัย
# 96  2022     10           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 97  2022     10           UY             URUGUAY            อุรุกวัย
# 98  2022     10           VU             VANUATU            วานูอาตู
# 99  2022     10           LI       LIECHTENSTEIN         ลิกเตนสไตน์
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.513069e+09          2.918375e+10       9.248671e+10
# ...

# %% [markdown]
# เดือน พฤศจิกายน

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=11&limit=100"
result = requests.get(url)
value_balance11 = result.json()
data_value_balance11 = pd.DataFrame.from_dict(value_balance11)
data_value_balance11
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022     11           CN               CHINA                 จีน
# 1   2022     11           US              U.S.A.        สหรัฐอเมริกา
# 2   2022     11           JP               JAPAN             ญี่ปุ่น
# 3   2022     11           MY            MALAYSIA            มาเลเซีย
# 4   2022     11           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022     11           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 96  2022     11           UY             URUGUAY            อุรุกวัย
# 97  2022     11           PY            PARAGUAY            ปารากวัย
# 98  2022     11           VU             VANUATU            วานูอาตู
# 99  2022     11           LI       LIECHTENSTEIN         ลิกเตนสไตน์
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.686762e+09          3.187051e+10       1.019145e+11
# ...

# %% [markdown]
# เดือน ธันวาคม

# %%
url = "https://dataapi.moc.go.th/summary-countries?year=2022&month=12&limit=100"
result = requests.get(url)
value_balance12 = result.json()
data_value_balance12 = pd.DataFrame.from_dict(value_balance12)
data_value_balance12
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022     12           CN               CHINA                 จีน
# 1   2022     12           US              U.S.A.        สหรัฐอเมริกา
# 2   2022     12           JP               JAPAN             ญี่ปุ่น
# 3   2022     12           MY            MALAYSIA            มาเลเซีย
# 4   2022     12           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022     12           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 96  2022     12           ZM              ZAMBIA             แซมเบีย
# 97  2022     12           UY             URUGUAY            อุรุกวัย
# 98  2022     12           CM            CAMEROON            แคเมอรูน
# 99  2022     12           VU             VANUATU            วานูอาตู
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.559588e+09          3.443010e+10       9.149067e+10
# ...

# %%
df_concat = pd.concat([data_value_balance1, data_value_balance2, data_value_balance3, data_value_balance4, data_value_balance5,
                       data_value_balance6, data_value_balance7, data_value_balance8, data_value_balance9,
                       data_value_balance10, data_value_balance11, data_value_balance12], axis=0)

# df_concat.to_excel('concat_file.xlsx', index=True)

df_concat
# Out:
#     year  month country_code     country_name_en     country_name_th  \
# 0   2022      1           CN               CHINA                 จีน
# 1   2022      1           JP               JAPAN             ญี่ปุ่น
# 2   2022      1           US              U.S.A.        สหรัฐอเมริกา
# 3   2022      1           MY            MALAYSIA            มาเลเซีย
# 4   2022      1           VN             VIETNAM            เวียดนาม
# ..   ...    ...          ...                 ...                 ...
# 95  2022     12           DO  DOMINICAN REPUBLIC  สาธารณรัฐโดมินิกัน
# 96  2022     12           ZM              ZAMBIA             แซมเบีย
# 97  2022     12           UY             URUGUAY            อุรุกวัย
# 98  2022     12           CM            CAMEROON            แคเมอรูน
# 99  2022     12           VU             VANUATU            วานูอาตู
#
#     value_usd_export  acc_value_usd_export  value_baht_export  \
# 0       2.473292e+09          2.473292e+09       8.240713e+10
# ...

# %%
# month 1
value_baht_export1 = data_value_balance1['value_baht_export'].sum()
value_baht_import1 = data_value_balance1['value_baht_import'].sum()
value_baht_balance1 = data_value_balance1['value_baht_balance'].sum()
# month 2
value_baht_export2 = data_value_balance2['value_baht_export'].sum()
value_baht_import2 = data_value_balance2['value_baht_import'].sum()
value_baht_balance2 = data_value_balance2['value_baht_balance'].sum()
# month 3
value_baht_export3 = data_value_balance3['value_baht_export'].sum()
value_baht_import3 = data_value_balance3['value_baht_import'].sum()
value_baht_balance3 = data_value_balance3['value_baht_balance'].sum()
# month 4
value_baht_export4 = data_value_balance4['value_baht_export'].sum()
value_baht_import4 = data_value_balance4['value_baht_import'].sum()
value_baht_balance4 = data_value_balance4['value_baht_balance'].sum()
# month 5
value_baht_export5 = data_value_balance5['value_baht_export'].sum()
value_baht_import5 = data_value_balance5['value_baht_import'].sum()
value_baht_balance5 = data_value_balance5['value_baht_balance'].sum()
# month 6
value_baht_export6 = data_value_balance6['value_baht_export'].sum()
value_baht_import6 = data_value_balance6['value_baht_import'].sum()
value_baht_balance6 = data_value_balance6['value_baht_balance'].sum()
# month 7
value_baht_export7 = data_value_balance7['value_baht_export'].sum()
value_baht_import7 = data_value_balance7['value_baht_import'].sum()
value_baht_balance7 = data_value_balance7['value_baht_balance'].sum()
# month 8
value_baht_export8 = data_value_balance8['value_baht_export'].sum()
value_baht_import8 = data_value_balance8['value_baht_import'].sum()
value_baht_balance8 = data_value_balance8['value_baht_balance'].sum()
# month 9
value_baht_export9 = data_value_balance9['value_baht_export'].sum()
value_baht_import9 = data_value_balance9['value_baht_import'].sum()
value_baht_balance9 = data_value_balance9['value_baht_balance'].sum()
# month 10
value_baht_export10 = data_value_balance10['value_baht_export'].sum()
value_baht_import10 = data_value_balance10['value_baht_import'].sum()
value_baht_balance10 = data_value_balance10['value_baht_balance'].sum()
# month 11
value_baht_export11 = data_value_balance11['value_baht_export'].sum()
value_baht_import11 = data_value_balance11['value_baht_import'].sum()
value_baht_balance11 = data_value_balance11['value_baht_balance'].sum()
# month 12
value_baht_export12 = data_value_balance12['value_baht_export'].sum()
value_baht_import12 = data_value_balance12['value_baht_import'].sum()
value_baht_balance12 = data_value_balance12['value_baht_balance'].sum()

# %% [markdown]
# # กราฟ line ดุลการค้าของไทย ย้อยหลัง 12 เดือน (ปี2565)

# %%
data_value_baht_export = {'mouth': ['มกราคม', 'กุมภาพันธ์', 'มีนาคม', 'เมษายน', 'พฤษภาคม', 'มิถุนายน', 'กรกฎาคม', 'สิงหาคม', 'กันยายน', 'ตุลาคม','พฤศจิกายน','ธันวาคม'],
        'value_baht_export': [value_baht_export1,value_baht_export2,value_baht_export3, value_baht_export4, value_baht_export5, value_baht_export6, value_baht_export7, value_baht_export8, value_baht_export9, value_baht_export10, value_baht_export11, value_baht_export12]
       }
data_value_baht_import = {'mouth': ['มกราคม', 'กุมภาพันธ์', 'มีนาคม', 'เมษายน', 'พฤษภาคม', 'มิถุนายน', 'กรกฎาคม', 'สิงหาคม', 'กันยายน', 'ตุลาคม','พฤศจิกายน','ธันวาคม'],
        'value_baht_import': [value_baht_import1,value_baht_import2,value_baht_import3, value_baht_import4, value_baht_import5, value_baht_import6, value_baht_import7, value_baht_import8, value_baht_import9, value_baht_import10, value_baht_import11, value_baht_import12]
       }
data_value_baht_balance = {'mouth': ['มกราคม', 'กุมภาพันธ์', 'มีนาคม', 'เมษายน', 'พฤษภาคม', 'มิถุนายน', 'กรกฎาคม', 'สิงหาคม', 'กันยายน', 'ตุลาคม','พฤศจิกายน','ธันวาคม'],
        'value_baht_balance': [value_baht_balance1,value_baht_balance2,value_baht_balance3, value_baht_balance4, value_baht_balance5, value_baht_balance6, value_baht_balance7, value_baht_balance8, value_baht_balance9, value_baht_balance10, value_baht_balance11, value_baht_balance12]
       }

data_value_baht_export_mouth = data_value_baht_export['mouth']
data_value_baht_export_value = data_value_baht_export['value_baht_export']

new_data_value_baht_export_value=list()
for i1 in data_value_baht_export_value:
  a1=i1/1000000000000
  new_data_value_baht_export_value.append(a1)



data_value_baht_import_mouth =data_value_baht_import['mouth']
data_value_baht_import_value = data_value_baht_import['value_baht_import']

new_data_value_baht_import_value=list()
for i2 in data_value_baht_import_value:
  a2=i2/1000000000000
  new_data_value_baht_import_value.append(a2)



data_value_baht_balance_mouth =data_value_baht_balance['mouth']
data_value_baht_balance_value = data_value_baht_balance['value_baht_balance']

new_data_value_baht_balance_value=list()
for i3 in data_value_baht_balance_value:
  a3=i3/1000000000000
  new_data_value_baht_balance_value.append(a3)



# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(name='ส่งออก', x=data_value_baht_export_mouth, y=new_data_value_baht_export_value))
fig.add_trace(go.Scatter(name='นำเข้า', x=data_value_baht_import_mouth, y=new_data_value_baht_import_value))
fig.add_trace(go.Scatter(name='ดุลการค้า', x=data_value_baht_balance_mouth, y=new_data_value_baht_balance_value))

fig.update_traces(
        textfont=dict(size=10),
        hovertemplate='มูลค่า: %{y:,.2f} ล้านล้านบาท<br>เดือน: %{x}'
    )

fig.update_layout(title={'text':'ดุลการค้าของไทย ย้อยหลัง 12 เดือน (ปี2565)',
                         'y':0.9,
                          'x':0.5,
                         'xanchor':'center',
                         'yanchor':'top'},
                   xaxis_title='เดือน',
                   yaxis_title='มูลค่า (บาท)',
                  yaxis = dict(tickformat = ',.0f'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # สินค้านำเข้า 10 อันดับแรก ปี 2565

# %%
# !gdown 1jSz_grDmTq-JKLW4ERLsQGjkQYVoBELD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jSz_grDmTq-JKLW4ERLsQGjkQYVoBELD
# To: /content/import2565.csv
# 100% 12.0k/12.0k [00:00<00:00, 26.3MB/s]

# %% [markdown]
# Table import2565_csv

# %%
import2565_csv = pd.read_csv('import2565.csv')
import2565_csv['ชื่อรายการ'] = import2565_csv['ชื่อรายการ'].str.replace('\d+', '')
import2565_csv['2565'] = import2565_csv['2565'].str.replace(',','').astype(int)
import2565_csv = import2565_csv.rename(columns={'2565': 'มูลค่า'})

# import2565_csv.to_excel('import_product_file.xlsx', index=True)
import2565_csv
# Out:
#                                            ชื่อรายการ       มูลค่า
# 0                                     01 สัตว์มีชีวิต     95254108
# 1        02 เนื้อสัตว์และส่วนอื่นของสัตว์ที่บริโภคได้    687736783
# 2   03 ปลา สัตว์น้ำจำพวกปู กุ้ง หอย และสัตว์น้ำที่...  10419657613
# 3          04 ผลิตภัณฑ์นม ไข่สัตว์ปีก น้ำผึ้งธรรมชาติ   2626070366
# 4   05 ผลิตภัณฑ์จากสัตว์ที่ไม่ได้ระบุหรือรวมไว้ในท...    209043556
# ..                                                ...          ...
# 91  93 อาวุธและกระสุน รวมทั้งส่วนประกอบและอุปกรณ์ป...    292750688
# 92            94 เฟอร์นิเจอร์ ฟูก เครื่องประทีป โคมไฟ   5247118032
# 93  95 ของเล่น ของเล่นเกม และของใช้ที่จำเป็นในการเ...   1023442678
# 94                              96 ผลิตภัณฑ์เบ็ดเตล็ด   1455289173
# 95      97 ศิลปกรรม ของที่นักสะสมรวบรวม และโบราณวัตถุ      8554808
#
# [96 rows x 2 columns]

# %%
top_10_import2565 = import2565_csv.sort_values('มูลค่า', ascending=False).head(10)
top_10_import2565
# Out:
#                                            ชื่อรายการ        มูลค่า
# 83  85 เครื่องจักรไฟฟ้า เครื่องอุปกรณ์ไฟฟ้า และส่ว...  181530938003
# 26   27 เชื้อเพลิงที่ได้จากแร่ น้ำมันแร่ และผลิตภัณฑ์   95970356074
# 82          84 เครื่องจักร เครื่องใช้กล และส่วนประกอบ   93508664175
# 71                               72 เหล็กและเหล็กกล้า   42405505696
# 70        71 อัญมณี ไข่มุก เครื่องประดับ และโลหะมีค่า   35107765116
# 38                   39 พลาสติกและของที่ทำด้วยพลาสติก   33177904065
# 85                            87 ยานยนต์และส่วนประกอบ   28776963077
# 72                     73 ของทำด้วยเหล็กหรือเหล็กกล้า   23110311695
# 73                        74 ทองแดงและชองทำด้วยทองแดง   21070241919
# 75              76 อะลูมิเนียมและของทำด้วยอะลูมิเนียม   19282591294

# %% [markdown]
# # กราฟ pie สินค้านำเข้า 10 อันดับแรก ปี 2565 (บาท)

# %%
fig = px .pie(top_10_import2565, values='มูลค่า', names='ชื่อรายการ',hole=.3, title = 'สินค้านำเข้า 10 อันดับแรก ปี 2565 (บาท)')

fig.update_traces(
                  textfont=dict(size=10),
                  hovertemplate='ชื่อรายการ: %{label}<br>มูลค่า: %{value:,.2f} บาท<br>สัดส่วน: %{percent:.2%}')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # สินค้าส่งออก 10 อันดับแรก ปี 2565

# %%
# !gdown 1RQYR3BT0w96xPRsKsL9kks1f63jjxwIO
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RQYR3BT0w96xPRsKsL9kks1f63jjxwIO
# To: /content/export2565.csv
# 100% 12.0k/12.0k [00:00<00:00, 28.1MB/s]

# %% [markdown]
# Table export2565_csv

# %%
export2565_csv = pd.read_csv('export2565.csv')
export2565_csv['ชื่อรายการ'] = export2565_csv['ชื่อรายการ'].str.replace('\d+', '')

export2565_csv['2565'] = export2565_csv['2565'].str.replace(',','').astype(int)
export2565_csv = export2565_csv.rename(columns={'2565': 'มูลค่า'})
# export2565_csv.to_excel('export_product_file.xlsx', index=True)
export2565_csv
# Out:
#                                            ชื่อรายการ      มูลค่า
# 0                                     01 สัตว์มีชีวิต   285818202
# 1        02 เนื้อสัตว์และส่วนอื่นของสัตว์ที่บริโภคได้  2693769969
# 2   03 ปลา สัตว์น้ำจำพวกปู กุ้ง หอย และสัตว์น้ำที่...  4051425746
# 3          04 ผลิตภัณฑ์นม ไข่สัตว์ปีก น้ำผึ้งธรรมชาติ   970924127
# 4   05 ผลิตภัณฑ์จากสัตว์ที่ไม่ได้ระบุหรือรวมไว้ในท...   129169471
# ..                                                ...         ...
# 91  93 อาวุธและกระสุน รวมทั้งส่วนประกอบและอุปกรณ์ป...     1040612
# 92            94 เฟอร์นิเจอร์ ฟูก เครื่องประทีป โคมไฟ  5236854129
# 93  95 ของเล่น ของเล่นเกม และของใช้ที่จำเป็นในการเ...  2271627235
# 94                              96 ผลิตภัณฑ์เบ็ดเตล็ด  1467543438
# 95      97 ศิลปกรรม ของที่นักสะสมรวบรวม และโบราณวัตถุ    19217276
#
# [96 rows x 2 columns]

# %%
top_10_export2565 = export2565_csv.sort_values('มูลค่า', ascending=False).head(10)
top_10_export2565
# Out:
#                                            ชื่อรายการ        มูลค่า
# 83  85 เครื่องจักรไฟฟ้า เครื่องอุปกรณ์ไฟฟ้า และส่ว...  114752384592
# 82          84 เครื่องจักร เครื่องใช้กล และส่วนประกอบ  111165003355
# 85                            87 ยานยนต์และส่วนประกอบ   76657955175
# 39                              40 ยางและของทำด้วยยาง   54129622106
# 38                   39 พลาสติกและของที่ทำด้วยพลาสติก   43807416491
# 70        71 อัญมณี ไข่มุก เครื่องประดับ และโลหะมีค่า   26090907407
# 26   27 เชื้อเพลิงที่ได้จากแร่ น้ำมันแร่ และผลิตภัณฑ์   23188495720
# 15            16 ของปรุงแต่งจากสัตว์น้ำ เช่น ปลา กุ้ง   17255666510
# 28                               29 เคมีภัณฑ์อินทรีย์   13551960178
# 72                     73 ของทำด้วยเหล็กหรือเหล็กกล้า   13407938275

# %% [markdown]
# # กราฟ pie สินค้าส่งออก 10 อันดับแรก ปี 2565 (บาท)

# %%
fig = px .pie(top_10_export2565, values='มูลค่า', names='ชื่อรายการ',hole=.3, title = 'สินค้าส่งออก 10 อันดับแรก ปี 2565 (บาท)')

fig.update_traces(
                  textfont=dict(size=10),
                  hovertemplate='ชื่อรายการ: %{label}<br>มูลค่า: %{value:,.2f} บาท<br>สัดส่วน: %{percent:.2%}')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # สินค้านำเข้า 10 อันดับแรก ปี 2560-2565

# %%
# !gdown 1l5cZDSLnZXUB8FNOwF-LBf6TcwFh0vMf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1l5cZDSLnZXUB8FNOwF-LBf6TcwFh0vMf
# To: /content/มูลค่าการนำเข้า แยกตามพิกัดสินค้า.csv
# 100% 20.1k/20.1k [00:00<00:00, 51.0MB/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# %%
df_product_import = pd.read_csv('มูลค่าการนำเข้า แยกตามพิกัดสินค้า.csv')
df_product_import['2565'] = df_product_import['2565'].str.replace(',','').astype(int)
df_product_import['2564'] = df_product_import['2564'].str.replace(',','').astype(int)
df_product_import['2563'] = df_product_import['2563'].str.replace(',','').astype(int)
df_product_import['2562'] = df_product_import['2562'].str.replace(',','').astype(int)
df_product_import['2561'] = df_product_import['2561'].str.replace(',','').astype(int)
df_product_import['2560'] = df_product_import['2560'].str.replace(',','').astype(int)

df_product_import['ชื่อรายการ'] = df_product_import['ชื่อรายการ'].str.replace('\d+', '')
# df_product_import.to_excel('import60_66_product_file.xlsx', index=True)
df_product_import = df_product_import.sort_values(['2565','2564','2563','2562','2561','2560'], ascending=False).head(10)
df_product_import
# Out:
#                                            ชื่อรายการ          2565  \
# 83  85 เครื่องจักรไฟฟ้า เครื่องอุปกรณ์ไฟฟ้า และส่ว...  181530938003
# 26   27 เชื้อเพลิงที่ได้จากแร่ น้ำมันแร่ และผลิตภัณฑ์   95970356074
# 82          84 เครื่องจักร เครื่องใช้กล และส่วนประกอบ   93508664175
# 71                               72 เหล็กและเหล็กกล้า   42405505696
# 70        71 อัญมณี ไข่มุก เครื่องประดับ และโลหะมีค่า   35107765116
# 38                   39 พลาสติกและของที่ทำด้วยพลาสติก   33177904065
# 85                            87 ยานยนต์และส่วนประกอบ   28776963077
# 72                     73 ของทำด้วยเหล็กหรือเหล็กกล้า   23110311695
# 73                        74 ทองแดงและชองทำด้วยทองแดง   21070241919
# 75              76 อะลูมิเนียมและของทำด้วยอะลูมิเนียม   19282591294
#
#              2564           2563           2562           2561           2560
# 83  1694385777624  1357674602589  1347058126963  1475407356286  1433426576444
# ...

# %%
# fig = px .pie(top_10_export2565, values='มูลค่า', names='ชื่อรายการ',hole=.3, title = 'สินค้าส่งออก 10 อันดับแรก ปี 2565 (บาท)')

# fig.update_traces(
#                   textfont=dict(size=10),
#                   hovertemplate='ชื่อรายการ: %{label}<br>มูลค่า: %{value:,.2f} บาท<br>สัดส่วน: %{percent:.2%}')

# fig.show()

# สร้าง dropdown widget สำหรับเลือก column
column_dropdown = widgets.Dropdown(
    options=list(df_product_import.columns[1:]),
    description='เลือก ปี:',
)

# สร้าง function สำหรับสร้าง pie chart ขึ้นอยู่กับ column ที่เลือก
def create_pie_chart(column):
    # แยกข้อมูลใน column และตั้งชื่อให้เป็น index
    data = df_product_import.set_index('ชื่อรายการ')[column]
    # สร้าง pie chart ด้วย Plotly Express และแสดงผล

    fig = px.pie(df_product_import, values=column, names='ชื่อรายการ', hole=.3, title='สินค้านำเข้าสูงสุด 10 อันดับแรก ปี 2560-2565')
    fig.update_traces(
        textfont=dict(size=10),
        hovertemplate='ชื่อรายการ: %{label}<br>มูลค่า: %{value:,.2f} บาท<br>สัดส่วน: %{percent:.2%}'
    )
    fig.update_layout(title=dict(text="สินค้านำเข้าสูงสุด 10 อันดับแรก (ปี 2560-2565)", x=0.5))
    fig.show()

# ใช้ interact function เพื่อเชื่อม column_dropdown กับ create_pie_chart function
widgets.interact(create_pie_chart, column=column_dropdown)
# Out:
# interactive(children=(Dropdown(description='เลือก ปี:', options=('2565', '2564', '2563', '2562', '2561', '2560…
# <function __main__.create_pie_chart(column)>

# %% [markdown]
# #สินค้าส่งออก 10 อันดับแรก ปี 2560-2565

# %%
# !gdown 1oih9aYaXRIMt2IbPk2FiaAdvXGZBXeE_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oih9aYaXRIMt2IbPk2FiaAdvXGZBXeE_
# To: /content/มูลค่าการส่งออก แยกตามพิกัดสินค้า.csv
# 100% 20.0k/20.0k [00:00<00:00, 49.9MB/s]

# %%
df_product_export = pd.read_csv('มูลค่าการส่งออก แยกตามพิกัดสินค้า.csv')
df_product_export['2565'] = df_product_export['2565'].str.replace(',','').astype(int)
df_product_export['2564'] = df_product_export['2564'].str.replace(',','').astype(int)
df_product_export['2563'] = df_product_export['2563'].str.replace(',','').astype(int)
df_product_export['2562'] = df_product_export['2562'].str.replace(',','').astype(int)
df_product_export['2561'] = df_product_export['2561'].str.replace(',','').astype(int)
df_product_export['2560'] = df_product_export['2560'].str.replace(',','').astype(int)

df_product_export['ชื่อรายการ'] = df_product_export['ชื่อรายการ'].str.replace('\d+', '')
# df_product_export.to_excel('export60_66_product_file.xlsx', index=True)

df_product_export = df_product_export.sort_values(['2565','2564','2563','2562','2561','2560'], ascending=False).head(10)
df_product_export
# Out:
#                                            ชื่อรายการ          2565  \
# 83  85 เครื่องจักรไฟฟ้า เครื่องอุปกรณ์ไฟฟ้า และส่ว...  114752384592
# 82          84 เครื่องจักร เครื่องใช้กล และส่วนประกอบ  111165003355
# 85                            87 ยานยนต์และส่วนประกอบ   76657955175
# 39                              40 ยางและของทำด้วยยาง   54129622106
# 38                   39 พลาสติกและของที่ทำด้วยพลาสติก   43807416491
# 70        71 อัญมณี ไข่มุก เครื่องประดับ และโลหะมีค่า   26090907407
# 26   27 เชื้อเพลิงที่ได้จากแร่ น้ำมันแร่ และผลิตภัณฑ์   23188495720
# 15            16 ของปรุงแต่งจากสัตว์น้ำ เช่น ปลา กุ้ง   17255666510
# 28                               29 เคมีภัณฑ์อินทรีย์   13551960178
# 72                     73 ของทำด้วยเหล็กหรือเหล็กกล้า   13407938275
#
#              2564           2563           2562           2561           2560
# 83  1282410699626  1065005228037  1048999807891  1131617020168  1152753246468
# ...

# %%
# สร้าง dropdown widget สำหรับเลือก column
column_dropdown = widgets.Dropdown(
    options=list(df_product_export.columns[1:]),
    description='เลือก ปี:',
)

# สร้าง function สำหรับสร้าง pie chart ขึ้นอยู่กับ column ที่เลือก
def create_pie_chart(column):
    # แยกข้อมูลใน column และตั้งชื่อให้เป็น index
    data = df_product_export.set_index('ชื่อรายการ')[column]
    names = [f"{i+1}. {name}" for i, name in enumerate(data.index)]
    # สร้าง pie chart ด้วย Plotly Express และแสดงผล

    fig = px.pie(df_product_export, values=column, names='ชื่อรายการ', hole=.3, title='สินค้าส่งออก 10 อันดับแรก ปี 2560-2565')
    fig.update_traces(
        textfont=dict(size=10),
        hovertemplate='ชื่อรายการ: %{label}<br>มูลค่า: %{value:,.2f} บาท<br>สัดส่วน: %{percent:.2%}'
    )
    fig.update_layout(title=dict(text="สินค้าส่งออกสูงสุด 10 อันดับแรก (ปี 2560-2565)", x=0.5))
    fig.show()

# ใช้ interact function เพื่อเชื่อม column_dropdown กับ create_pie_chart function
widgets.interact(create_pie_chart, column=column_dropdown)
# Out:
# interactive(children=(Dropdown(description='เลือก ปี:', options=('2565', '2564', '2563', '2562', '2561', '2560…
# <function __main__.create_pie_chart(column)>

# %% [markdown]
# # ตลาดส่งออกสำคัญ 10 อันดับแรก

# %%
new_df_export60_66['baht_amnt'] = new_df_export60_66['baht_amnt'].astype(float)

df_export_sum_name = new_df_export60_66.groupby('name').sum()
df_export_sum_name = df_export_sum_name['baht_amnt']
df_export_sum_name
# Out:
# name
# กรีซ                                  1.232505e+10
# กรีนแลนด์                             1.646290e+08
# กวม                                   1.553557e+09
# กัมพูชา                               1.185641e+12
# กัวเดอลุป                             3.013931e+08
#                                           ...
# ไมโครนีเซีย (สหพันธรัฐไมโครนีเซีย)    3.735618e+07
# ไลบีเรีย                              4.782742e+08
# ไอซ์แลนด์                             4.822689e+09
# ไอร์แลนด์                             3.337890e+11
# ไอล์ออฟแมน                            5.213790e+05
# Name: baht_amnt, Length: 253, dtype: float64

# %%
data_export_sum_name = pd.DataFrame(list(df_export_sum_name.items()), columns=['name','baht_amnt'])
data_export_sum_name
# Out:
#                                    name     baht_amnt
# 0                                  กรีซ  1.232505e+10
# 1                             กรีนแลนด์  1.646290e+08
# 2                                   กวม  1.553557e+09
# 3                               กัมพูชา  1.185641e+12
# 4                             กัวเดอลุป  3.013931e+08
# ..                                  ...           ...
# 248  ไมโครนีเซีย (สหพันธรัฐไมโครนีเซีย)  3.735618e+07
# 249                            ไลบีเรีย  4.782742e+08
# 250                           ไอซ์แลนด์  4.822689e+09
# 251                           ไอร์แลนด์  3.337890e+11
# 252                          ไอล์ออฟแมน  5.213790e+05
#
# [253 rows x 2 columns]

# %%
data_export_sum_name.sort_values('baht_amnt', ascending=False).head(10)
# Out:
#                 name     baht_amnt
# 37           ญี่ปุ่น  9.221043e+12
# 125         สิงคโปร์  7.850803e+12
# 113     สหรัฐอเมริกา  6.305565e+12
# 25               จีน  3.591885e+12
# 161           ฮ่องกง  2.480275e+12
# 92          มาเลเซีย  1.579303e+12
# 206         เวียดนาม  1.461178e+12
# 121  สาธารณรัฐเกาหลี  1.276742e+12
# 3            กัมพูชา  1.185641e+12
# 151      อินโดนีเซีย  1.042890e+12

# %%
import plotly.express as px

top_10_export_countries = data_export_sum_name.sort_values('baht_amnt', ascending=False).head(10)

fig = px.bar(top_10_export_countries,
             x=top_10_export_countries['baht_amnt']/1000000000000, y='name',
             title='ตลาดส่งออกสำคัญ 10 อันดับแรก ปี 2565', orientation='h',color='name')

fig.update_xaxes(title='มูลค่า (ล้านล้านบาท)', tickformat='.2fM')
fig.update_yaxes(title='ประเทศ')

fig.update_traces(
        textfont=dict(size=10),
        hovertemplate='มูลค่า: %{x:,.2f} ล้านล้านบาท<br>ประเทศ: %{y}'
    )

fig.update_layout(
    title={
        'text': 'ตลาดส่งออกสำคัญ 10 อันดับแรก ปี 2565',
        'x': 0.5, # กำหนดให้อยู่ตรงกลางของ plot
    })
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
